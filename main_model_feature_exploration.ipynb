# %%
import pandas as pd

# %%
df=pd.read_csv('model_all.csv')
df.shape
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (0,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (189122, 16)

# %%
df.info()
# є null, там де учасники приймали участь тільки один раз і не виграли
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189122 entries, 0 to 189121
# Data columns (total 16 columns):
# average_activity        189122 non-null object
# average_winner_price    166840 non-null float64
# count_lots              189122 non-null int64
# count_unique_hosts      189122 non-null int64
# economy_percent         166826 non-null float64
# economy_value           166826 non-null float64
# favourite_host          189122 non-null int64
# first_activity_days     189122 non-null object
# last_activity_days      189122 non-null object
# lose                    189122 non-null int64
# lose_open               189122 non-null int64
# unique_id               189122 non-null object
# win                     189122 non-null int64
# win_not_open            189122 non-null int64
# win_open                189122 non-null int64
# y                       189122 non-null int64
# dtypes: float64(3), int64(9), object(4)
# memory usage: 23.1+ MB

# %%
df.describe()
# Out:
#        average_winner_price     count_lots  count_unique_hosts  \
# count          1.668400e+05  189122.000000       189122.000000
# mean           6.932877e+05      14.646614            5.796248
# std            4.869424e+07     102.794482           33.427069
# min            1.000000e-02       1.000000            1.000000
# 25%            1.390934e+04       1.000000            1.000000
# 50%            5.653325e+04       3.000000            1.000000
# 75%            1.500000e+05       9.000000            3.000000
# max            1.902526e+10   17635.000000         4345.000000
#
#        economy_percent  economy_value  favourite_host           lose  \
# count     1.668260e+05   1.668260e+05   189122.000000  189122.000000
# mean      6.911968e+01  -7.510215e+04        0.582629       5.392577
# std       2.034501e+04   4.754572e+07        0.493126      54.258455
# min       2.631579e-09  -1.902523e+10        0.000000      -1.000000
# 25%       9.907143e-01   0.000000e+00        0.000000       0.000000
# 50%       1.000000e+00   0.000000e+00        1.000000       0.000000
# 75%       1.000000e+00   9.176445e+02        1.000000       2.000000
# max       7.179335e+06   3.705131e+08        1.000000   10458.000000
#
#            lose_open            win   win_not_open       win_open  \
# count  189122.000000  189122.000000  189122.000000  189122.000000
# mean        5.389949       9.254037       6.455843       2.798194
# std        54.254010      55.964506      38.255000      27.900154
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       1.000000       1.000000       0.000000
# 50%         0.000000       2.000000       1.000000       0.000000
# 75%         2.000000       6.000000       5.000000       1.000000
# max     10458.000000    9861.000000    6354.000000    4866.000000
#
#                    y
# count  189122.000000
# mean        0.332642
# std         0.471161
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %%
df.corr()
# heat_map намалювати
# Out:
#                       average_winner_price  count_lots  count_unique_hosts  \
# average_winner_price              1.000000    0.001336            0.001639
# count_lots                        0.001336    1.000000            0.854424
# count_unique_hosts                0.001639    0.854424            1.000000
# economy_percent                   0.920779    0.001470            0.001657
# economy_value                    -0.965512   -0.000944           -0.001843
# favourite_host                   -0.004027   -0.117881           -0.163843
# lose                              0.001520    0.930409            0.813967
# lose_open                         0.001518    0.930141            0.813702
# win                               0.000981    0.934734            0.780235
# win_not_open                      0.000337    0.700795            0.580985
# win_open                          0.001505    0.914080            0.768451
# y                                 0.000268    0.127290            0.135712
#
#                       economy_percent  economy_value  favourite_host  \
# average_winner_price         0.920779      -0.965512       -0.004027
# count_lots                   0.001470      -0.000944       -0.117881
# count_unique_hosts           0.001657      -0.001843       -0.163843
# economy_percent              1.000000      -0.943103       -0.003810
# economy_value               -0.943103       1.000000        0.003541
# favourite_host              -0.003810       0.003541        1.000000
# lose                         0.000480      -0.000550       -0.101791
# lose_open                    0.000480      -0.000550       -0.101751
# win                          0.002235      -0.001201       -0.117833
# win_not_open                 0.002764      -0.001202       -0.097881
# win_open                     0.000693      -0.000760       -0.102151
# y                            0.000044       0.001124       -0.346153
#
#                           lose  lose_open       win  win_not_open  win_open  \
# average_winner_price  0.001520   0.001518  0.000981      0.000337  0.001505
# count_lots            0.930409   0.930141  0.934734      0.700795  0.914080
# count_unique_hosts    0.813967   0.813702  0.780235      0.580985  0.768451
# economy_percent       0.000480   0.000480  0.002235      0.002764  0.000693
# economy_value        -0.000550  -0.000550 -0.001201     -0.001202 -0.000760
# favourite_host       -0.101791  -0.101751 -0.117833     -0.097881 -0.102151
# lose                  1.000000   0.999998  0.739442      0.408200  0.923536
# lose_open             0.999998   1.000000  0.738951      0.407482  0.923535
# win                   0.739442   0.738951  1.000000      0.891451  0.783582
# win_not_open          0.408200   0.407482  0.891451      1.000000  0.417008
# win_open              0.923536   0.923535  0.783582      0.417008  1.000000
# y                     0.088544   0.088503  0.147960      0.142665  0.101177
#
#                              y
# average_winner_price  0.000268
# count_lots            0.127290
# count_unique_hosts    0.135712
# economy_percent       0.000044
# economy_value         0.001124
# favourite_host       -0.346153
# lose                  0.088544
# lose_open             0.088503
# win                   0.147960
# win_not_open          0.142665
# win_open              0.101177
# y                     1.000000

# %%
# збалансованість даних
print(df['y'].value_counts())
# збалансованість, якщо забирати учасників з 1,2 лотами
print(df[df['count_lots']>2]['y'].value_counts())
# Out:
# 0    126212
# 1     62910
# Name: y, dtype: int64
# 1    51193
# 0    48652
# Name: y, dtype: int64

# %%
# count_unique_hosts розподіл
print(df['count_unique_hosts'].value_counts()[:15])
print(df[df['count_lots']>2]['count_unique_hosts'].value_counts())
# Out:
# 1     98755
# 2     28556
# 3     14635
# 4      9011
# 5      6391
# 6      4484
# 7      3556
# 8      2817
# 9      2273
# 10     1862
# 11     1557
# 12     1296
# 13     1041
# 14      952
# 15      820
# Name: count_unique_hosts, dtype: int64
# 1       19734
# 2       18300
# 3       14635
# 4        9011
# 5        6391
# 6        4484
# 7        3556
# 8        2817
# 9        2273
# 10       1862
# 11       1557
# 12       1296
# 13       1041
# 14        952
# 15        820
# 16        709
# 17        619
# 18        551
# 19        526
# 20        439
# 21        423
# 23        380
# 22        373
# 25        340
# 24        301
# 26        269
# 27        258
# 28        244
# 29        232
# 31        206
#         ...
# 358         1
# 361         1
# 233         1
# 808         1
# 744         1
# 296         1
# 807         1
# 743         1
# 551         1
# 487         1
# 359         1
# 295         1
# 806         1
# 486         1
# 1381        1
# 1055        1
# 1060        1
# 676         1
# 931         1
# 739         1
# 482         1
# 418         1
# 545         1
# 353         1
# 289         1
# 1120        1
# 416         1
# 288         1
# 703         1
# 3230        1
# Name: count_unique_hosts, Length: 470, dtype: int64

# %%
# favourite hosts
print(df['favourite_host'].value_counts())
print(df[df['count_lots']>10]['favourite_host'].value_counts())
# Out:
# 1    110188
# 0     78934
# Name: favourite_host, dtype: int64
# 0    34526
# 1     8411
# Name: favourite_host, dtype: int64

# %%
df[(df['count_lots']==1)&(df['win_open']+df['win_not_open']==0)]['y'].value_counts()
# Out:
# 0    10151
# 1      930
# Name: y, dtype: int64
